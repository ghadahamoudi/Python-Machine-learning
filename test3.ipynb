# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
np.random.seed(0)
m = 100
x = np.linspace(0,10,m).reshape(m,1)
y = x**2 + np.random.randn(m,1)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
model = SVR(C=100)
model.fit(x,y)
model.score(x,y)
predictions = model.predict(x)
plt.scatter(x,y)
plt.plot(x, predictions , c='r')
# Out:
# C:\Users\ghada\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
